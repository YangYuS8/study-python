# %% [markdown]
# ### 第1题
#
# 下列代码可以成功执行,则 myfile.data文件的保存目录是哪一个选项?( )
# ```
# open("myfile.data", "ab")
# ```
#
# - A. 与程序文件在相同的目录下
# - B. C盘根目录下
# - C. 由path路径指明
# - D. Python安装目录下
#
# **答案: A**

# %% [markdown]
# ### 第2题
#
# 执行下列语句后,文件1.dat中的内容是哪一项?( )
# ```
# fo=open("1.dat", "w")
# x=["open",",","read",",","write"]
# fo.write(" ".join(x))
# fo.close()
# ```
#
# - A. "open""read""write"
# - B. open read write
# - C. ["open",",","read",",","write"]
# - D. open, read, write
#
# **答案: B**

# %% [markdown]
# ### 第3题
#
# 下列方法中,用于获取文件当前目录的是哪一个选项?( )
#
# - A. os.getcwd()
# - B. os.mkdir()
# - C. os.listdir()
# - D. os.mkdir(path)
#
# **答案: A**

# %% [markdown]
# ### 第4题
#
# 以下选项中,不是 Python 中文件操作的相关函数的( )。
#
# - A. load()
# - B. open()
# - C. read()
# - D. write()
#
# **答案: A**

# %% [markdown]
# ### 第5题
#
# 使用 open() 函数打开 Windows 操作系统的文件,路径名不正确的是哪一项?( )
#
# - A. open("d:\\Python\\a.txt",'w')
# - B. open("d:\\Python\\a.txt",'w')
# - C. open("d:/Python/a.txt",'w')
# - D. open(r"d:\\Python\\a.txt",'w')
#
# **答案: A**

# %% [markdown]
# ### 第6题
#
# 运行下面的程序，其输出结果为（ ）。
# ```
# a=[1,2,3,4,5]
# try:
#     print(a[5])
# except IndexError:
#     print("索引下标出界")
# ```
#
# - A. 没有输出，抛出异常信息
# - B. 5
# - C. 索引下标出界
# - D. 4
#
# **答案: C**

# %% [markdown]
# ### 第7题
#
# 运行下面的程序后，输出的最后一行信息是（ ）。
# ```
# ls=[2,5,4,5,0,10]
# try:
#     for i in range(10):
#         print(10/ls[i])
# except IndexError:
#     print("下标越界访问")
# except ZeroDivisionError:
#     print("除零错误")
# else:
#     print("程序正常执行")
# ```
#
# - A. 下标越界访问
# - B. 除零错误
# - C. 程序正常执行
# - D. 1
#
# **答案: B**

# %% [markdown]
# ### 第8题
#
# 以下选项中,不是Python中文件操作的相关函数的( )。
#
# - A. open()
# - B. writeline()
# - C. write()
# - D. readlines()
#
# **答案: B**

# %% [markdown]
# ### 第9题
#
# 下列说法中,不正确的是哪一项?( )
#
# - A. 使用write()方法写入文件时,数据会追加到文件的末尾
# - B. 使用read()方法可以一次性读取文件中的所有数据
# - C. 使用readlines()方法可以一次性读取文件中的所有数据
# - D. 以'w'模式打开一个可读/写的文件,如果文件存在会被覆盖
#
# **答案: A**

# %% [markdown]
# ### 第10题
#
# 下列Python关键字中，用于异常处理结构中捕获特定类型异常的是( )。
#
# - A. while
# - B. def
# - C. pass
# - D. except
#
# **答案: D**

# %% [markdown]
# ### 第11题
#
# 当文件不存在时,下列哪种模式在使用 open() 方法打开文件时会报异常? ( )
#
# - A. 'w+'
# - B. 'r'
# - C. 'a'
# - D. 'w'
#
# **答案: B**

# %% [markdown]
# ### 第12题
#
# 模块os不能进行的操作( )。
#
# - A. 删除空文件夹
# - B. 删除文件
# - C. 复制文件
# - D. 查询工作路径
#
# **答案: C**

# %% [markdown]
# ### 第13题
#
# 以下选项中,不是 Python 文件打开模式的( )。
#
# - A. 'r'
# - B. 'w'
# - C. '+'
# - D. 'c'
#
# **答案: D**

# %% [markdown]
# ### 第14题
#
# 对于特别大的文本文件,以下选项中描述正确的( )。
#
# - A. Python无法处理特别大的文本文件
# - B. Python可以处理特别大的文件,不用特别关心
# - C. 选择内存大的计算机,一次性读入再进行操作
# - D. 使用for...in循环,分行读入,逐行处理
#
# **答案: D**

# %% [markdown]
# ### 第15题
#
# file是文本文件对象,下列选项中,哪一项用于读取文件的一行? ( )
#
# - A. file.read()
# - B. file.readline(80)
# - C. file.readlines()
# - D. file.readline()
#
# **答案: D**

# %% [markdown]
# ### 第16题
#
# 给出如下代码,以下哪一项是不正确的选项?(）
# ```
# name = input("请输入要打开的文件:")
# fi = open(name)
# for line in fi.readlines():
#     print(line)
# fi.close()
# ```
#
# - A. fi.readlines()的内容是一个序列,可以使用type(fi.readlines())查看其类型
# - B. 用户输入文件名称,以文本文件方式读入文件的内容并逐行输出
# - C. 代码for line in fi.readlines()可以写为 for line in fi
# - D. 通过fi.readlines()方法将文件的全部内容读入一个字典 fi中
#
# **答案: D**

# %% [markdown]
# ### 第17题
#
# 以下关于Python文件打开模式的描述,错误的( )。
#
# - A. 覆盖写模式为w
# - B. 创建写模式为n
# - C. 追加写模式为a
# - D. 只读模式为r
#
# **答案: B**

# %% [markdown]
# ### 第18题
#
# 文件exam.txt与下面的程序在同一目录,其内容是一段文本: Learning Python,以下最可能的输出结果是哪一项? ( )
# ```
# fo=open("exam.txt")
# print(fo)
# fo.close()
# ```
#
# - A. \<_io.TextIOWrapper...\>
# - B. exam.txt
# - C. exam
# - D. Learning Python
#
# **答案: A**

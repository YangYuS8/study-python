# %% [markdown]
# ### 第1题
#
# 在以下C类继承A类和B类的格式中,正确的是哪一项?
#
# - A. class C extends A, B:
# - B. class C implements A, B:
# - C. class C(A, B):
# - D. class C(A:B):
#
# **答案: C**

# %% [markdown]
# ### 第2题
#
# 对下面的代码分析正确的是( )。
# ```
# class A:
#     def __init__(self):
#         self.x = 1
#         self.__y = 1
#     def getY(self):
#         return self.__y
# a = A()
# a.__y = 45
# print(a.getY())
# ```
#
# - A. 程序运行结果为 45。
# - B. 程序运行结果为 1。
# - C. 程序有错误,因为y是私有的,不能在类之外访问。
# - D. 程序有错误,不能使用__y作为变量名。
#
# **答案: B**

# %% [markdown]
# ### 第3题
#
# 在类中，具有4个形式参数的实例方法通常在调用时有( )个实际参数。
#
# - A. 不确定
# - B. 3
# - C. 4
# - D. 5
#
# **答案: B**

# %% [markdown]
# ### 第4题
#
# 关于下面程序的说法中，不正确的是哪一项？
# ```
# class Hello:
#     def __init__(self, id, color="yellow"):
#         self.id = id
#         self.color = color
#     def Hello(self, weight):
#         return 20+weight
# # 主程序
# h=Hello(100)
# print(h.color)
# ```
#
# - A. Hello(self, weight) 是成员方法
# - B. 代码 h=Hello(100)无法通过编译
# - C. 初始化方法是__init__(self, id, color="yellow")
# - D. print(h.color)语句的输出结果是 yellow
#
# **答案: B**

# %% [markdown]
# ### 第5题
#
# Python中定义私有属性的方法是哪一项？
#
# - A. 使用__XX定义属性名
# - B. 使用__XX__定义属性名
# - C. 使用public关键字
# - D. 使用 private 关键字
#
# **答案: A**

# %% [markdown]
# ### 第6题
#
# 将细节隐藏在类定义中，术语称为（）。
#
# - A. 虚函数
# - B. 封装
# - C. 子类化
# - D. 继承
#
# **答案: B**

# %% [markdown]
# ### 第7题
#
# 下面代码段运行的结果是()。
# ```
# class A:
#     def __init__(self):
#         self.i = 1
#     def m(self):
#         self.i = 10
# class B(A):
#     def m(self):
#         self.i +=1
#         return self.i
# def main():
#     b = B()
#     print(b.m())
# main()
# ```
#
# - A. 2
# - B. 3
# - C. 1
# - D. 10
#
# **答案: A**

# %% [markdown]
# ### 第8题
#
# ()不是面向对象程序设计的基本特征之一。
#
# - A. 多态
# - B. 封装
# - C. 抽象
# - D. 继承
#
# **答案: C**

# %% [markdown]
# ### 第9题
#
# __init__方法的作用是哪一项？
#
# - A. 引用对象
# - B. 显示对象初始信息
# - C. 初始化对象
# - D. 初始化类
#
# **答案: C**

# %% [markdown]
# ### 第10题
#
# 对下面的代码分析正确的是（）。
# ```
# class A:
#     def __init__(self, s):
#         self.s = s
#     def print(self):
#         print(s)
# a= A("Welcome")
# a.print()
# ```
#
# - A. 程序有错误，类 A 中print(self)方法应该修改为 print(s)。
# - B. 程序有错误，类 A 中print(self)方法应该修改为 print(self, s)。
# - C. 程序有错误，类 A 方法print中print(s)语句应该修改为 print(self.s)。
# - D. 程序有错误，因为类 A 中没有构造方法。
#
# **答案: C**

# %% [markdown]
# ### 第11题
#
# 下面代码段运行的结果是()。
# ```
# class A:
#     def __init__(self, i=1):
#         self.i = 1
# class B(A):
#     def __init__(self, j=2):
#         super().__init__()
#         self.j = j
# def main():
#     b = B()
#     print(b.i,b.j)
# main()
# ```
#
# - A. 0 0
# - B. 2 1
# - C. 0 1
# - D. 1 2
#
# **答案: D**

# %% [markdown]
# ### 第12题
#
# 对下面的代码分析正确的是()。
# ```
# class A:
#     def __init__(self):
#         self.x = 1
#         self.__y = 1
#     def getY(self):
#         return self.__y
# a = A()
# print(a.x)
# ```
#
# - A. 程序有错误,不能使用_y作为变量名。
# - B. 程序运行结果为0。
# - C. 程序有错误,因为y是私有的,不能在类之外访问。
# - D. 程序运行结果为1。
#
# **答案: D**

# %% [markdown]
# ### 第13题
#
# 对下面的代码分析正确的是（ ）。
# ```
# class A:
#     def __init__(self):
#         self.x = 1
#         self.__y = 1
#     def getY(self):
#         return self.__y
# a = A()
# print(a.__y)
# ```
#
# - A. 程序运行结果为1。
# - B. 程序运行结果为0。
# - C. 程序有错误,因为 y 是私有的,不能在类之外访问。
# - D. 程序有错误，不能使用__y作为变量名。
#
# **答案: C**

# %% [markdown]
# ### 第14题
#
# 下面代码段运行的结果是()。
# ```
# def main():
#     myCount = Count()
#     times= 0
#     for i in range(0, 100):
#         increment(myCount, times)
#     print(myCount.count, times)
# def increment(c, times):
#     c.count += 1
#     times += 1
# class Count:
#     def __init__(self):
#         self.count = 0
# main()
# ```
#
# - A. 101 0
# - B. 100 0
# - C. 100 100
# - D. 101 101
#
# **答案: B**

# %% [markdown]
# ### 第15题
#
# 不属于面向对象程序设计的特征的是哪一项？
#
# - A. 重写
# - B. 封装
# - C. 多态
# - D. 继承
#
# **答案: A**

# %% [markdown]
# ### 第16题
#
# 下面代码段运行的结果是()。
# ```
# class A:
#     def __new__(cls):
#         print("A's __new__() invoked")
#         return object().__new__(cls)
#     def __init__(self):
#         print("A's __init__() invoked")
# class B(A):
#     def __new__(cls):
#         print("B's __new__() invoked")
#         return object().__new__(cls)
#     def __init__(self):
#         print("B's __init__() invoked")
# def main():
#     b=B()
# main()
# ```
#
# - A. A's __new__() invoked\nA's __init__() invoked\nB's __new__() invoked\nB's __init__() invoked
# - B. B's __new__() invoked\nB's __init__() invoked
# - C. A's __new__() invoked\nA's __init__() invoked
# - D. A's __new__() invoked\nB's __init__() invoked
#
# **答案: B**

# %% [markdown]
# ### 第17题
#
# 下面哪个选项是正确的？
#
# - A. 每个类中总有一个默认构造方法
# - B. 一个类中如果没有定义构造方法,那么系统就会提供一个默认构造方法
# - C. Python中的构造方法名与类名是相同的
# - D. 类中至少定义一个构造方法
#
# **答案: B**

# %% [markdown]
# ### 第18题
#
# 在Python中，使用保留字（ ）来定义类。
#
# - A. init
# - B. def
# - C. class
# - D. object
#
# **答案: C**

# %% [markdown]
# ### 第19题
#
# 下列选项中，用于标识为静态方法是哪一项？
#
# - A. @staticmethod
# - B. @privatemethod
# - C. @classmethod
# - D. @instancemethod
#
# **答案: A**

# %% [markdown]
# ### 第20题
#
# 定义一个类的"私有"方法，Python 的惯例是使用（ ）开始方法的名称。
#
# - A. private
# - B. 两个下划线(__)
# - C. 井号(#)
# - D. 一个下划线(_)
#
# **答案: B**

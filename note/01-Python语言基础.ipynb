# %% [markdown]
# ### 第1题
#
# 正确的标识符是( )。
#
# - A. my-name
# - B. _item
# - C. 2you
# - D. abc*234
#
# **答案: B**

# %% [markdown]
# ### 第2题
#
# 关于Python字符串,下列说法错误的是( )。
#
# - A. 既可以用单引号,又可以用双引号创建字符串
# - B. 字符串以0标志字符串结束
# - C. 在三引号字符串中可以包含换行、回车等特殊字符
# - D. 字符串长度为1的字符串
#
# **答案: B**

# %% [markdown]
# ### 第3题
#
# 已知a=3,b=4,c=5,与print("a=",a,"b=",b,"c=",c)语句输出结果不一样的是( )。
#
# - A. print('a={a} b={b} c={c}')
# - B. print("a=%d b=%d c=%d" %(a,b,c))
# - C. print(f'a={a} b={b} c={c}')
# - D. print('a={0} b={1} c={2}'.format(3,4,5))
#
# **答案: A**

# %% [markdown]
# ### 第4题
#
# Python语句a=121+1.21;print(type(a))的输出结果是。
#
# - A. <class'long'>
# - B. <class'double'>
# - C. <class'int'>
# - D. <class'float'>
#
# **答案: D**

# %% [markdown]
# ### 第5题
#
# 不是面向对象的程序设计语言是( )。
#
# - A. Python
# - B. C++
# - C. Java
# - D. C
#
# **答案: D**

# %% [markdown]
# ### 第6题
#
# 下列能打印出smith\exam1\test.txt的语句是( )。
#
# - A. print("smith"\exam1"\test.txt")
# - B. print("smith\\\exam1\\\test.txt")
# - C. print("smith\\"exam1\\"test.txt")
# - D. print("smith\exam1\test.txt")
#
# **答案: A**

# %% [markdown]
# ### 第7题
#
# Python表达式sqrt(4)*sqrt(9)的值为_。
#
# - A. 6
# - B. 6.0
# - C. 13.0
# - D. 36.0
#
# **答案: B**

# %% [markdown]
# ### 第8题
#
# Python语句print(type(1/2))的输出结果是__。
#
# - A. <class 'double'>
# - B. <class 'float'>
# - C. <class 'int'>
# - D. <class 'number'>
#
# **答案: C**

# %% [markdown]
# ### 第9题
#
# 语句x=input()执行时,如果从键盘输入 12 并按 Enter键,则x的值是( )。
#
# - A. 12
# - B. (12)
# - C. 12.0
# - D. "12"
#
# **答案: D**

# %% [markdown]
# ### 第10题
#
# 在Python中关于单引号与双引号的说法,正确的( )。
#
# - A. 单引号用于短字符串,双引号用于长字符串
# - B. 单引号针对变量,双引号针对常量
# - C. Python中字符串初始化只能使用单引号
# - D. 单、双引号在使用上没有区别
#
# **答案: D**

# %% [markdown]
# ### 第11题
#
# Python语句print(0xA+0xB)的输出结果是_。
#
# - A. 0xA+0xB
# - B. 0xA0xB
# - C. A+B
# - D. 21
#
# **答案: D**

# %% [markdown]
# ### 第12题
#
# 语句 print(1,2,3, end=":"​)的输出结果是( )。
#
# - A. 123:
# - B. 123
# - C. 1:2:3
# - D. 1,2,3
#
# **答案: A**

# %% [markdown]
# ### 第13题
#
# Python程序的扩展名是( )。
#
# - A. Jpg
# - B. py
# - C. docx
# - D. exe
#
# **答案: B**

# %% [markdown]
# ### 第14题
#
# Python的输出函数是( )。
#
# - A. math()
# - B. input()
# - C. print()
# - D. turtle()
#
# **答案: C**

# %% [markdown]
# ### 第15题
#
# ( )是不等长编码。
#
# - A. ASCII码
# - B. 前三种编码都不是
# - C. UTF-8码
# - D. Big5码
#
# **答案: C**

# %% [markdown]
# ### 第16题
#
# Python语句print(type(1j))的输出结果是__。
#
# - A. <class 'float'>
# - B. <class 'complex'>
# - C. <class 'dict'>
# - D. <class 'int'>
#
# **答案: B**

# %% [markdown]
# ### 第17题
#
# 若字符串s="atc",则len(s)的值是( )。
#
# - A. 3
# - B. 4
# - C. 7
# - D. 6
#
# **答案: A**

# %% [markdown]
# ### 第18题
#
# 有如下语句:n=6  print(eval("n***"))  执行后的输出是( )。
#
# - A. \*'\*'\*'\*'\*'\*'
# - B. ******
# - C. n*'*'
# - D. 6*'*'
#
# **答案: B**

# %% [markdown]
# ### 第19题
#
# Python语句print(type(1/2))的输出结果是__。
#
# - A. <class 'float'>
# - B. <class 'int'>
# - C. <class 'number'>
# - D. <class 'double'>
#
# **答案: A**

# %% [markdown]
# ### 第20题
#
# 下面代码的输出结果( )。a = "ac" b = "bd" c = a + b print(c)
#
# - A. dbac
# - B. bdac
# - C. acbd
# - D. abcd
#
# **答案: C**

# %% [markdown]
# ### 第21题
#
# x是整数,与关系表达式x==0等价的表达式是( )。
#
# - A. x=0
# - B. x!=1
# - C. x
# - D. not x
#
# **答案: D**

# %% [markdown]
# ### 第22题
#
# ( )表示后面部分是注释。
#
# - A. &
# - B. %
# - C. *
# - D. #
#
# **答案: D**

# %% [markdown]
# ### 第23题
#
# Python语言的官方网站是( )。
#
# - A. www.python.com
# - B. www.python.edu
# - C. www.python.org
# - D. pythonic.org
#
# **答案: C**

# %% [markdown]
# ### 第24题
#
# 下列数据类型中,Python不支持的是()。
#
# - A. int
# - B. float
# - C. char
# - D. list
#
# **答案: C**

# %% [markdown]
# ### 第25题
#
# Python语句x='car'; y=2; print(x+y)的输出结果是__。
#
# - A. 语法错
# - B. 'car2'
# - C. 2
# - D. 'carcar'
#
# **答案: A**

# %% [markdown]
# ### 第26题
#
# 已有x=5,以下不合法的表达式是( )。
#
# - A. 3<=x<=10
# - B. x in [1,2,3,4,5]
# - C. 3<=x and x<=10
# - D. 5=x
#
# **答案: D**

# %% [markdown]
# ### 第27题
#
# 关于Python中的复数,下列说法错误的是( )。
#
# - A. 表示复数的语法是real+image j
# - B. 方法real返回复数的实部
# - C. 虚部必须加后缀j,且必须是小写
# - D. 实部和虚部都是浮点数
#
# **答案: C**

# %% [markdown]
# ### 第28题
#
# Python语句print(chr(65))的运行结果是____。
#
# - A. a
# - B. 6
# - C. A
# - D. 65
#
# **答案: C**

# %% [markdown]
# ### 第29题
#
# 要将3.1415926变成00003.14,应如何进行格式化输出?
#
# - A. "%8.2f"% 3.1415926
# - B. "%0.2f"%3.1415926
# - C. "%.2f"%3.1415926
# - D. "%08.2f"%3.1415926
#
# **答案: D**

# %% [markdown]
# ### 第30题
#
# 语句 eval("2+4/5")执行后的输出结果是( )。
#
# - A. 2+4/5
# - B. "2+4/5"
# - C. 2.8
# - D. 2
#
# **答案: C**

# %% [markdown]
# ### 第31题
#
# 在 Python中,变量的平方的表达式是( )。
#
# - A. a
# - B. a*2
# - C. a**2
# - D. a^2
#
# **答案: C**

# %% [markdown]
# ### 第32题
#
# 字符串"我喜欢Python语言"的长度( )。
#
# - A. 14
# - B. 11
# - C. 22
# - D. 16
#
# **答案: B**

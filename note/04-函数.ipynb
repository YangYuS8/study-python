# %% [markdown]
# ### 第1题
#
# 下面程序的运行结果是( )
# ```
# def scope():
#     n=4
#     m=5
#     print(m,n, end='')
# n=5
# t=8
# scope()
# print(n,t)
# ```
#
# - A. 4558
# - B. 5458
# - C. 5448
# - D. 4548
#
# **答案: B**

# %% [markdown]
# ### 第2题
#
# 下面说法中错误的是( )。
#
# - A. 函数体至少有一个return语句
# - B. 函数可以返回多个值
# - C. 函数体可以包含多个return语句
# - D. 函数体可以没有return语句
#
# **答案: A**

# %% [markdown]
# ### 第3题
#
# area 是 tri模块中的一个函数,执行 from tri import area 后,调用 area()函数应该使用()。
#
# - A. tri(area)
# - B. tri()
# - C. area()
# - D. tri.area()
#
# **答案: C**

# %% [markdown]
# ### 第4题
#
# 下面程序段的运行结果是()。
# ```
# def fun(x,y):
#     if x>=y: return x
#     else: return fun(x+1,y-1) *2
# print(fun(1,10))
# ```
#
# - A. 32
# - B. 96
# - C. 160
# - D. 192
#
# **答案: D**

# %% [markdown]
# ### 第5题
#
# 在 Python 中,对于函数定义代码的理解,正确的是()。
#
# - A. 必须存在 return 语句
# - B. 形参和 return 语句都是可有可无的
# - C. 必须存在形参
# - D. 形参和 return 语句要么都存在,要么都不存在
#
# **答案: B**

# %% [markdown]
# ### 第6题
#
# 下面程序段的运行结果是( )。
# ```
# x=10
# y=20
# def swap():
#     x,y=y,x
# print(x,y)
# ```
#
# - A. 20 10
# - B. 10 10
# - C. 10 20
# - D. 语法错误
#
# **答案: C**

# %% [markdown]
# ### 第7题
#
# 下面程序段的运行结果是( )。
# ```
# def f1(m):
#     s=m if m>0 else 1
#     def f2():
#         nonlocal s
#         s=s*2
#         return s
#     for s in range(4):
#         print(f2(), end='')
# f1(-1)
# ```
#
# - A. 出现异常
# - B. 0246
# - C. 2468
# - D. 24816
#
# **答案: B**

# %% [markdown]
# ### 第8题
#
# 下面程序段的运行结果是( )。
# ```
# s=0
# def f(n):
#     global s
#     for i in range(1,n+1):
#         s=s+i
#     return s
# print(f(f(3)))
# ```
#
# - A. 出现异常
# - B. 27
# - C. 6
# - D. 21
#
# **答案: B**

# %% [markdown]
# ### 第9题
#
# 下面程序的运行结果是( )。
# ```
# a=10
# def func():
#     global a
#     a=20
#     print(a, end='')
# func()
# print(a)
# ```
#
# - A. 20 10
# - B. 20 20
# - C. 20
# - D. 20
#
# **答案: B**

# %% [markdown]
# ### 第10题
#
# 下面程序段的运行结果是( )。
# ```
# def c2(m):
#     s = 1
#     for i in range(1, m + 1): s *= 1
#     return s
# def c1(m,n):
#     if m<n:
#         m,n=n,m
#     return c2(m)/c2(n)/c2(m-n)
# print(c1(2,4))
# ```
#
# - A. 0
# - B. 6.0
# - C. 1
# - D. 6
#
# **答案: D**

# %% [markdown]
# ### 第11题
#
# 下面程序段的运行结果是( )。
# ```
# def fun(x,y):
#     x=y
#     y=x
# x=10
# y=20
# fun(x,y)
# print(x,y)
# ```
#
# - A. 20 10
# - B. 20 20
# - C. 运行异常
# - D. 10 20
#
# **答案: D**

# %% [markdown]
# ### 第12题
#
# 下面属于函数错误的调用方式的是( )。
# ```
# def fun(a,b,c=3,d=4):
#     return(a+b-c-d)
# ```
#
# - A. fun(1,2,5,c=3)
# - B. fun(1,2)
# - C. fun(1,b=2)
# - D. fun(1,2,3)
#
# **答案: A**

# %% [markdown]
# ### 第13题
#
# 下面程序段的运行结果是( )。
# ```
# dct={'a':60,'b':90,'c':70,'d':80}
# print(sorted(dct, key=lambda x:dct[x], reverse=True))
# ```
#
# - A. [90,80,70,60]
# - B. [80,70,90,60]
# - C. ['d', 'c', 'b', 'a']
# - D. ['b', 'd', 'c','a']
#
# **答案: D**

# %% [markdown]
# ### 第14题
#
# print(type(lambda:3))的输出结果是()。
#
# - A. \<class 'NoneType'\>
# - B. \<class 'float'\>
# - C. \<class 'function'\>
# - D. \<class 'int'\>
#
# **答案: C**

# %% [markdown]
# ### 第15题
#
# 下面程序的运行结果是( )。
# ```
# li=[1]
# def scope1():
#     li.append(6)
#     print(li, end='')
# scope1()
# print(li)
# ```
#
# - A. [6] [1]
# - B. [6] [1,6]
# - C. [1,6] [1]
# - D. [1,6] [1,6]
#
# **答案: D**

# %% [markdown]
# ### 第16题
#
# (lambda x:x%3==1 and x%5==1 and x%7==1)(211)的运行结果是( )。
#
# - A. False
# - B. True
# - C. None
# - D. 出现异常
#
# **答案: B**

# %% [markdown]
# ### 第17题
#
# 函数定义如下：
# ```
# def f1(a,b,c):
#     print(a+b)
# nums=(1,2,3)
# f1(*nums)
# ```
# 程序运行的结果是()。
#
# - A. 语法错
# - B. 6
# - C. 3
# - D. 1
#
# **答案: C**

# %% [markdown]
# ### 第18题
#
# 判断一个函数的形参k是否是整型,应该使用下面的( )。
#
# - A. k='int'
# - B. k is int
# - C. type(k)='int'
# - D. type(k)=='int'
#
# **答案: D**

# %% [markdown]
# ### 第19题
#
# 定义一个求阶乘的函数的头部,应该使用下面的( )。
#
# - A. def f(k) as int:
# - B. define fact():
# - C. def f(k):
# - D. def fact():
#
# **答案: C**

# %% [markdown]
# ### 第20题
#
# 函数可以改变()类型的形式参数变量绑定的实参。
#
# - A. int
# - B. list
# - C. float
# - D. string
#
# **答案: B**

# %% [markdown]
# ### 第21题
#
# 在一个函数中若局部变量和全局变量同名,则()。
#
# - A. 全局变量屏蔽局部变量
# - B. 局部变量屏蔽全局变量
# - C. 全局变量和局部变量都不可用
# - D. 程序错误
#
# **答案: B**

# %% [markdown]
# ### 第22题
#
# 下面程序段的运行结果是( )。
# ```
# def fun(x):
#     return 2**x
# print(fun(fun(3)))
# ```
#
# - A. 8
# - B. 64
# - C. 256
# - D. 128
#
# **答案: C**

# %% [markdown]
# ### 第23题
#
# 下面程序的运行结果是( )。
# ```
# def ins_sort_rec(seq, i):
#     if i ==0:return
#     ins_sort_rec(seq, i-1)
#     j=i
#     while j> 0 and seq[j-1]>seq[j]:
#         seq[j-1], seq[j] = seq[j], seq[j-1]
#         j=1
# seq=[3,-6,79,45,8,12,6,8]
# ins_sort_rec(seq, len(seq)-1)
# print(*seq)
# ```
#
# - A. -6
# - B. -6 3 6 8 8 12 45 79
# - C. 79 45 12 8 8 6 3 -6
# - D. 79
#
# **答案: B**

# %% [markdown]
# ### 第24题
#
# 选择代码段设计为函数的一个重要原则是（）。
#
# - A. 需要提供参数
# - B. 功能相对独立
# - C. 不宜太长
# - D. 具有返回值
#
# **答案: B**
